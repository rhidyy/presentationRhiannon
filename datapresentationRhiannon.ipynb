# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# # Which is The Best Cat Breed?

# %% [markdown]
# The best cat breed, for me, would depend on a few factors; health, life expectancy, shedding, family friendly, and playfulness.

# %%
catbreeds_df = pd.read_csv(r'C:\Users\rhian\Downloads\catbreeds.csv')

# %% [markdown]
# ## Health

# %%
catbreeds_df[catbreeds_df['general_health'] > 4]
# Out:
#                  name                               length             origin  \
# 4   American Wirehair                      Medium to large      United States
# 42          Pixie-Bob                      20 to 24 inches    Washington, USA
# 45           Savannah  13 to 20 inches, not including tail                USA
# 51           Snowshoe                       Medium to long  Philadelphia, USA
#
#     min_life_expectancy  max_life_expectancy  min_weight  max_weight  \
# 4                    14                   18         8.0          15
# 42                   13                   15         8.0          17
# 45                   17                   20         8.0          20
# 51                   14                   19         7.0          12
#
#     family_friendly  shedding  general_health  playfulness  children_friendly  \
# 4                 4         3               5            3                  4
# ...

# %% [markdown]
# ## Shedding

# %%
catbreeds_df[catbreeds_df['shedding'] < 2]
# Out:
#                    name           length          origin  min_life_expectancy  \
# 7                 Asian           Medium   Great Britain                   15
# 9               Bambino            Short   United States                    9
# 13  Brazilian Shorthair  Medium to large          Brazil                   14
# 20              Chausie            Large           Egypt                   12
# 24            Devon Rex  15 to 18 inches  Devon, England                    9
# 25              Donskoy           Medium          Russia                   12
# 32           Khao Manee  10 to 12 inches        Thailand                   10
# 39     Oriental Bicolor           Medium   United States                    8
# 41            Peterbald           Medium          Russia                   12
# 47            Serengeti           Medium   United States                   10
# 52               Sokoke           Medium           Kenya                    9
# ...

# %% [markdown]
# ## Family Friendliness

# %%
catbreeds_df[catbreeds_df['family_friendly'] > 4]
# Out:
#                     name                               length  \
# 1                 Aegean                               Medium
# 7                  Asian                               Medium
# 8        Australian Mist                               Medium
# 10           Bengal Cats  17 to 22 inches, not including tail
# 11                Birman                      15 to 18 inches
# 16               Burmese                      15 to 18 inches
# 21  Colorpoint Shorthair                      Small to medium
# 22           Cornish Rex                                Small
# 24             Devon Rex                      15 to 18 inches
# 27                Foldex                               Medium
# 30      Japanese Bobtail                               Medium
# 31              Javanese                      Small to medium
# 41             Peterbald                               Medium
# 42             Pixie-Bob                      20 to 24 inches
# ...

# %% [markdown]
# ## Playful

# %%
catbreeds_df[catbreeds_df['playfulness'] > 4]
# Out:
#                     name                               length  \
# 0             Abyssinian                      12 to 16 inches
# 10           Bengal Cats  17 to 22 inches, not including tail
# 17              Burmilla                               Medium
# 21  Colorpoint Shorthair                      Small to medium
# 22           Cornish Rex                                Small
# 23                Cyprus                               Medium
# 30      Japanese Bobtail                               Medium
# 32            Khao Manee                      10 to 12 inches
# 45              Savannah  13 to 20 inches, not including tail
# 49              Siberian                      17 to 25 inches
# 51              Snowshoe                       Medium to long
# 53                Somali                      11 to 14 inches
# 56             Tonkinese                      12 to 15 inches
# 58        Turkish Angora                               Medium
#
# ...

# %% [markdown]
# In the lists above, there are 37 different cats. 17 appear at least twice.

# %% [markdown]
# The below data is the only cat that appears three times on the lists above.

# %%
specific_row = catbreeds_df.loc[51]
print(specific_row)
# Out:
# name                            Snowshoe
# length                    Medium to long
# origin                 Philadelphia, USA
# min_life_expectancy                   14
# max_life_expectancy                   19
# min_weight                           7.0
# max_weight                            12
# family_friendly                        5
# shedding                               3
# general_health                         5
# playfulness                            5
# children_friendly                      5
# grooming                               5
# intelligence                           5
# other_pets_friendly                    4
# Name: 51, dtype: object

# %% [markdown]
# From the data above, the Snowshoe appears to be teh best cat based on my conditions. The snowshoes life expectancy avergaes out at 16.5.
